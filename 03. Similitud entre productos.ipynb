# %% [markdown]
# # SEMELHANÇA ENTRE PRODUTOS
#
# * [1. Carregando Pacotes e Fazendo Especificações](#chapter1)
# * [2. Importando os Dados e Fazendo as primeiras análises](#chapter2)
#     * [2.1. Convertendo os DataFrames em listas](#section_2_1)
#     * [2.2. Particionando os DataFrames](#section_2_2)
#     * [2.3. Loop em for para trazer os resultados esperados](#section_2_3)
# * [3. Trabalhando com matrizes](#chapter3)
# * [4. Usando Computação Distribuída](#chapter4)
#     * [4.1. Utilizando PySpark](#section_4_1)
#     * [4.2. Utilizando a função Jaro_Winkler para calcular a similaridade](#section_4_2)
#     * [4.3. Ordenando os resultados](#section_4_3)

# %% [markdown]
# # 1. Carregando Pacotes e Fazendo Especificações <a class="anchor" id="chapter1"></a>

# %%
import numpy as np 
import pandas as pd 
import csv
from datetime import datetime

import ray
import jellyfish
import sys
import itertools
import collections.abc

from time import sleep
from pyspark.sql import SparkSession
from pyspark.sql.functions import udf
from pyspark.sql.functions import col
from pyspark.sql.types import DoubleType

# %% [markdown]
# fazer a especificação unicode é essencial para poder fazer as comparações de strings com a função do pacote jellyfish

# %%
import sys
if sys.version_info[0] >= 3:
    unicode = str

# %%
import os
os.chdir('/Users/brunnokalyxton/Desktop/Data Science/13 - Mercado Livre/Desafio ds 2022')
os.getcwd()
# Out:
# '/Users/brunnokalyxton/Desktop/Data Science/13 - Mercado Livre/Desafio ds 2022'

# %%
pd.options.display.max_rows
pd.set_option('display.max_rows', None)

# %% [markdown]
# # 2. Importando os Dados e Fazendo as primeiras análises <a class="anchor" id="chapter2"></a>

# %%
df= pd.read_csv("items_titles.csv")
df.shape
# Out:
# (30000, 1)

# %%
df_teste= pd.read_csv("items_titles_test.csv")
df_teste.shape
# Out:
# (10000, 1)

# %% [markdown]
# ## 2.1. Convertendo os DataFrames em listas <a class="anchor" id="section_2_1"></a>

# %%
df_list = df.values.tolist()
df_teste_list = df.values.tolist()

# %% [markdown]
# ## 2.2. Particionando os DataFrames <a class="anchor" id="section_2_2"></a>

# %% [markdown]
# Irei trabalhar com apenas 1000 linhas em cada dataframe para testar o tempo de processamento da solução que será criada

# %%
partialA = df_list[0:1000] #arquivo parcial de items_titles.csv
partialB = df_teste_list[0:1000] #arquivo parcial de items_titles_test.csv

# %% [markdown]
# É preciso que cada string esteja em unicode para que seja processada pela função jaro_distance

# %%
PartialListA = [unicode(i) for i in partialA] 
PartiallistB = [unicode(i) for i in partialB]

# %% [markdown]
# ## 2.3. Loop em for para trazer os resultados esperados <a class="anchor" id="section_2_3"></a>

# %% [markdown]
# Foi desenvolvido dois loops for para que cada linha de um dataframe interasse com todas as linhas do outro dataframe. Desta maneira, como estamos com dois dataframes de 1000 linhas, é esperado um output de 1.000.000 de linhas.
#
# Irei acompanhar o tempo de processamento com a função time

# %%
# %%time
res    = []
lista1 = []
lista2 = []
for nickB in PartiallistB:
    for nickA in PartialListA:
        results = jellyfish.jaro_distance(nickA, nickB)
        res.append(results)
        lista1.append(nickA)
        lista2.append(nickB)
        
#         print (nickB,nickA,results)
# Out:
# CPU times: user 9.9 s, sys: 83.2 ms, total: 9.98 s
# Wall time: 10.1 s

# %% [markdown]
# O tempo de processamento para as 1000 entradas em cada dataframe foi de 8.33 segundos. Isso gera um problema para quando formos utilizar as 30000 linhas, pois irá gerar um output de 900.000.000. Há possibilidade de então trabalharmos com computação distribuida

# %%
final = list(zip(lista1,lista2, res))
simil = pd.DataFrame(final, columns=['A','B','Resultado'])
simil.drop(simil.loc[simil['Resultado']==1].index, inplace=True)
simil = simil.sort_values('Resultado', ascending = False)
simil.head(100)
# Out:
#                                                         A  \
# 209912                   ['Tênis Via Marte 21-7202 Knit']
# 912209                         ['Tênis Via Marte 217202']
# 228968    ['Tênis Usthemp Volare Temá\x81tico - Praia 2']
# 968228     ['Tênis Usthemp Volare Temá\x81tico - Snes 3']
# 658008  ['Tênis Usthemp Short Temá\x81tico - Maria Vir...
# 8658    ['Tênis Usthemp Slip-on Temá\x81tico - Maria V...
# 385275  ['Tênis Usthemp Long Temá\x81tico - Brigadeiro...
# 275385  ['Tênis Usthemp Long Temá\x81tico - Poodle Bra...
# 469998  ['Lançamento Tênis Caterpillar Intruder Origin...
# 998469  ['Lançamento Tênis Caterpillar Desert Original...
# 866056          ['Tenis Infantil Olympikus Spider Kids ']
# 56866              ['Tênis Infantil Olympikus Game Kids']
# 8139    ['Tênis Usthemp Short Temá\x81tico - Borboleta...
# 139008  ['Tênis Usthemp Short Temá\x81tico - Maria Vir...
# 445466       ['Tenis Masculino Olympikus Veloz- Corrida']
# 466445        ['Tenis Masculino Olympikus Astro Marinho']
# 518793  ['Tênis Usthemp Amy Temá\x81tico - Gato Siamês...
# 793518  ['Tênis Usthemp Amy Temá\x81tico - Poodle Cinza']
# 518644     ['Tênis Usthemp One Temá\x81tico - Pinguim 2']
# 644518  ['Tênis Usthemp Amy Temá\x81tico - Poodle Cinza']
# 378729  ['Tênis Puma Infantil St Runner V2 Mesh V- Uni...
# 729378     ['Tênis Infantil Puma St Runner V2 Mesh V Ps']
# 111102  ['Tênis Feminino Casual Flatform Beira Rio 424...
# 102111      ['Tênis Feminino Casual Beira Rio - 4205123']
# 417668        ['Tênis Feminino Moleca Promoção 5738.102']
# 668417                 ['Tênis Feminino Moleca 5712.205']
# 60611   ['Ténis Estilo All Star Cano Baixo Masculino D...
# 611060  ['Ténis Estilo All Star Cano Alto Masculino De...
# 805649  ['Tênis Usthemp Slip-on Vegano Casual Estampa ...
# 649805  ['Tênis Usthemp Half Vegano Casual Estampa Spi...
# 435738                          ['Tênis Nike Air Jordan']
# 738435                          ['Tênis Nike Air Max 38']
# 617625  ['Tênis Infantil Masculino Molekinho Nylon Mar...
# 625617  ['Tênis Infantil Masculino Molekinho Sola Trat...
# 673300  ['Tênis Olympikus Cs1 Feminino Corrida Caminha...
# 300673  ['Tênis Olympikus Asas Feminino De Corrida Ori...
# 658290  ['Tênis Usthemp Slip-on Temá\x81tico - Deepspa...
# 290658  ['Tênis Usthemp Slip-on Temá\x81tico - Maria V...
# 363561  ['Tênis Botinha Feminina Bota Treino Academia ...
# 561363  ['Tênis Botinha Feminina Bota Fitnes Academia ...
# 898644     ['Tênis Usthemp One Temá\x81tico - Pinguim 2']
# 644898  ['Tênis Usthemp One Temá\x81tico - Pirlo Welsh...
# 646625  ['Tênis Infantil Masculino Molekinho Nylon Mar...
# 625646  ['Tênis Infantil Menino Molekinho 2832106 Mari...
# 82646   ['Tênis Infantil Menino Molekinho 2832106 Mari...
# 646082  ['Tênis Infantil Menino Molekinho 2821104 Azul...
# 977884  ['Tênis Olympikus Sunna Feminino Vinho E Rosa ...
# 884977  ['Tênis Olympikus Venus Feminino Azul E Rosa -...
# 403371  ['Tênis Usthemp Spice Temá\x81tico -shih-tzu P...
# 371403  ['Tênis Usthemp Spice Temá\x81tico -  Cat&dog ...
#
# 580570              ['Tenis Fila Masculino Speed Trail ']   0.857038
# 201667  ['Tênis Feminino Caminhada Sapato Academia Lev...   0.853243
# 667201  ['Tênis Feminino Caminhada Amarrar Preto Pink ...   0.853243
# 377572   ['Tênis adidas Vs Pace Masculino Branco Eh0019']   0.852844
# 572377               ['Tênis adidas Vs Pace - Masculino']   0.852844
# 44913     ['Tênis Masculino Esportivo Actvitta 4907.101']   0.852810
# 913044  ['Tenis Masculino Marinho/caramelo Actvitta 49...   0.852810
# 361183  ['Tenis Feminino Caminhada Corrida Esporte Sup...   0.852483
# 183361  ['Tenis Feminino Caminhada Corrida Confortavel...   0.852483
# 241062              ['Sapatilha Scott Mtb Comp Boa 2021']   0.852131
# 62241          ['Sapatilha Mtb Scott Comp Boa Verm/ Pto']   0.852131
# 228644     ['Tênis Usthemp Volare Temá\x81tico - Snes 3']   0.851547
# 644228     ['Tênis Usthemp One Temá\x81tico - Pinguim 2']   0.851547
# 403290  ['Tênis Usthemp Spice Temá\x81tico -  Cat&dog ...   0.850250
# 290403  ['Tênis Usthemp Slip-on Temá\x81tico - Deepspa...   0.850250
# 370389                    ['Tênis Feminino Basic Branco']   0.848965
# 389370               ['Tênis Feminino Napa Branco/prata']   0.848965
# 75548   ['Tênis Anacapri Branco Corda Flatform Original']   0.848885
# 548075                    ['Tênis Anacapri Branco Capri']   0.848885
# 752220       ['Chuteira Infantil Molekinho Futsal Preto']   0.848854
# 220752       ['Chuteira Molekinho Preta Futsal Infantil']   0.848854
# 59299              ['Tênis Skechers Go Walk Joy Marinho']   0.848715
# 299059            ['Tênis Skechers Go Walk 5 - Feminino']   0.848715
# 139228  ['Tênis Usthemp Short Temá\x81tico - Borboleta...   0.848188
# 228139     ['Tênis Usthemp Volare Temá\x81tico - Snes 3']   0.848188
# 940420    ['Tênis Usthemp Half Temá\x81tico - Margarida']   0.847997
# 420940           ['Tênis Usthemp Clash Temático - Lhama']   0.847997
# 658968  ['Tênis Usthemp Slip-on Temá\x81tico - Maria V...   0.847739
# 968658    ['Tênis Usthemp Volare Temá\x81tico - Praia 2']   0.847739
# 198521  ['Tênis Infantil Red Nose Skate Casual 16467 R...   0.847412
# 521198                ['Tênis Infantil Red Nose Rnfj103']   0.847412
# 280298  ['Tênis Casual Feminino Moleca Napa Rosa 5731....   0.846060
# 298280  ['Tênis Casual Feminino Adulto Lona Moleca 573...   0.846060
# 403968  ['Tênis Usthemp Spice Temá\x81tico -  Cat&dog ...   0.845126
# 968403    ['Tênis Usthemp Volare Temá\x81tico - Praia 2']   0.845126
# 102890  ['Tênis Feminino Casual Flatform Beira Rio 424...   0.845022
# 890102  ['Tênis Feminino Casual Flatform Original Lanç...   0.845022
# 705067  ['Tênis Olympikus Decola Feminino - Verde E Co...   0.844881
# 67705   ['Tênis Olympikus Pride 2 Feminino Verde E Rosa']   0.844881
# 518385  ['Tênis Usthemp Amy Temá\x81tico - Poodle Cinza']   0.844881
# 385518  ['Tênis Usthemp Long Temá\x81tico - Poodle Bra...   0.844881
# 216738                               ['Tênis Nike Urbam']   0.843333
# 435216                          ['Tênis Nike Air Max 38']   0.843333
# 216435                               ['Tênis Nike Urbam']   0.843333
# 738216                          ['Tênis Nike Air Jordan']   0.843333

# %% [markdown]
# Após o primeiro processamento, transformo a lista em um dataframe de nome simil. Também são retirados as linhas onde os resultados são iguais a 1, pois representam comparação com resultado identico no outro dataframe. Por fim os dados são ordenamos pelo maior resultado ao menor.

# %% [markdown]
# # 3. Trabalhando com matrizes <a class="anchor" id="chapter3"></a>

# %% [markdown]
# Para tentar diminuir o tempo de processamento, irei transformar as listas parciais em matrizes e verificar se há melhora no desempenho

# %%
matPartialA = np.array(partialA)
matPartialB = np.array(partialB)

# %%
# %%time
matRes    = []
matLista1 = []
matLista2 = []
for matNickB in matPartialB:
    for matNickA in matPartialA:
        matResults = jellyfish.jaro_distance(str(matNickA), str(matNickB))
        matRes.append(matResults)
        matLista1.append(matNickA)
        matLista2.append(matNickB)
# Out:
# CPU times: user 54.7 s, sys: 278 ms, total: 55 s
# Wall time: 55.2 s

# %%
matFinal = list(zip(matLista1,matLista2, matRes))
matSimil = pd.DataFrame(matFinal, columns=['A','B','Resultado'])
matSimil.drop(simil.loc[simil['Resultado']==1].index, inplace=True)
matSimil = simil.sort_values('Resultado', ascending = False)
matSimil.head(100)
# Out:
#                                                         A  \
# 209912                   ['Tênis Via Marte 21-7202 Knit']
# 912209                         ['Tênis Via Marte 217202']
# 228968    ['Tênis Usthemp Volare Temá\x81tico - Praia 2']
# 968228     ['Tênis Usthemp Volare Temá\x81tico - Snes 3']
# 658008  ['Tênis Usthemp Short Temá\x81tico - Maria Vir...
# 8658    ['Tênis Usthemp Slip-on Temá\x81tico - Maria V...
# 385275  ['Tênis Usthemp Long Temá\x81tico - Brigadeiro...
# 275385  ['Tênis Usthemp Long Temá\x81tico - Poodle Bra...
# 469998  ['Lançamento Tênis Caterpillar Intruder Origin...
# 998469  ['Lançamento Tênis Caterpillar Desert Original...
# 866056          ['Tenis Infantil Olympikus Spider Kids ']
# 56866              ['Tênis Infantil Olympikus Game Kids']
# 8139    ['Tênis Usthemp Short Temá\x81tico - Borboleta...
# 139008  ['Tênis Usthemp Short Temá\x81tico - Maria Vir...
# 445466       ['Tenis Masculino Olympikus Veloz- Corrida']
# 466445        ['Tenis Masculino Olympikus Astro Marinho']
# 518793  ['Tênis Usthemp Amy Temá\x81tico - Gato Siamês...
# 793518  ['Tênis Usthemp Amy Temá\x81tico - Poodle Cinza']
# 518644     ['Tênis Usthemp One Temá\x81tico - Pinguim 2']
# 644518  ['Tênis Usthemp Amy Temá\x81tico - Poodle Cinza']
# 378729  ['Tênis Puma Infantil St Runner V2 Mesh V- Uni...
# 729378     ['Tênis Infantil Puma St Runner V2 Mesh V Ps']
# 111102  ['Tênis Feminino Casual Flatform Beira Rio 424...
# 102111      ['Tênis Feminino Casual Beira Rio - 4205123']
# 417668        ['Tênis Feminino Moleca Promoção 5738.102']
# 668417                 ['Tênis Feminino Moleca 5712.205']
# 611060  ['Ténis Estilo All Star Cano Alto Masculino De...
# 60611   ['Ténis Estilo All Star Cano Baixo Masculino D...
# 805649  ['Tênis Usthemp Slip-on Vegano Casual Estampa ...
# 649805  ['Tênis Usthemp Half Vegano Casual Estampa Spi...
# 435738                          ['Tênis Nike Air Jordan']
# 738435                          ['Tênis Nike Air Max 38']
# 617625  ['Tênis Infantil Masculino Molekinho Nylon Mar...
# 625617  ['Tênis Infantil Masculino Molekinho Sola Trat...
# 673300  ['Tênis Olympikus Cs1 Feminino Corrida Caminha...
# 300673  ['Tênis Olympikus Asas Feminino De Corrida Ori...
# 658290  ['Tênis Usthemp Slip-on Temá\x81tico - Deepspa...
# 290658  ['Tênis Usthemp Slip-on Temá\x81tico - Maria V...
# 363561  ['Tênis Botinha Feminina Bota Treino Academia ...
# 561363  ['Tênis Botinha Feminina Bota Fitnes Academia ...
# 644898  ['Tênis Usthemp One Temá\x81tico - Pirlo Welsh...
# 898644     ['Tênis Usthemp One Temá\x81tico - Pinguim 2']
# 646625  ['Tênis Infantil Masculino Molekinho Nylon Mar...
# 625646  ['Tênis Infantil Menino Molekinho 2832106 Mari...
# 82646   ['Tênis Infantil Menino Molekinho 2832106 Mari...
# 646082  ['Tênis Infantil Menino Molekinho 2821104 Azul...
# 977884  ['Tênis Olympikus Sunna Feminino Vinho E Rosa ...
# 884977  ['Tênis Olympikus Venus Feminino Azul E Rosa -...
# 403371  ['Tênis Usthemp Spice Temá\x81tico -shih-tzu P...
# 371403  ['Tênis Usthemp Spice Temá\x81tico -  Cat&dog ...
#
['Tênis Olympikus Pride 2 Feminino Verde E Rosa']   0.844881
# 518385  ['Tênis Usthemp Amy Temá\x81tico - Poodle Cinza']   0.844881
# 385518  ['Tênis Usthemp Long Temá\x81tico - Poodle Bra...   0.844881
# 216738                               ['Tênis Nike Urbam']   0.843333
# 435216                          ['Tênis Nike Air Max 38']   0.843333
# 216435                               ['Tênis Nike Urbam']   0.843333
# 738216                          ['Tênis Nike Air Jordan']   0.843333

# %%
simil.shape
# Out:
# (999000, 3)

# %%
matSimil.shape
# Out:
# (999000, 3)

# %% [markdown]
# O tempo de processamento quando trabalhando com matrizes subiu muito. Ainda assim, em tentativas de realizar o procedimento com todos os dados o tempo de processamento foi superior a 10 minutos, motivo pelo qual iremos trabalhar com computação distribuída.

# %% [markdown]
# # 4. Usando Computação Distribuída <a class="anchor" id="chapter4"></a>

# %% [markdown]
# Para trabalhar com computação distribuída irei transformar a solução do problema em uma função de dois argumentos, onde estes serão os dataframes (de 1 coluna com n linhas) que venham a ser comparados.
#
# A função irá realizar os seguintes procedimentos
#    * Iniciar 3 listas vazias (res, lista1, lista2)
#    * transformar os dois dataframes que entram na função em lista
#    * Aplicar Unicode nas duas listas geradas a partir do dataframe
#    * Para cada frase contida em cada lista, aplicar a função jaro_distance para comparar com todas as outras frases contidas na outra lista disponível, gerando assim os valores de resultados.
#    * Realizar o append dos resultados nas listas res, lista1 e lista2.
#    * Criar um dataframe a partir da concatenação das listas res, lista1 e lista2.
#    * Retirar do dataframe as linhas com resultados iguais a 1; e
#    * Ordenar a lista pela coluna Resultados, do maior para o menor.

# %%
# %%time
def similitud(x,y):
    res    = []
    lista1 = []
    lista2 = []
    xList = x.values.tolist()
    yList = y.values.tolist()
    UniListA = [unicode(i) for i in xList] 
    UniListB = [unicode(i) for i in yList]
    for titleB in UniListB:
        for titleA in UniListA:
            results = jellyfish.jaro_distance(titleA, titleB)
            res.append(results)
            lista1.append(titleA)
            lista2.append(titleB)
    final = list(zip(lista1,lista2, res))
    simil = pd.DataFrame(final, columns=['A','B','Resultado'])
    simil.drop(simil.loc[simil['Resultado']==1].index, inplace=True)
    simil = simil.sort_values('Resultado', ascending = False)
    return simil.head(100)
# Out:
# CPU times: user 5 µs, sys: 1e+03 ns, total: 6 µs
# Wall time: 9.06 µs

# %%
# %%time
similitud(df[0:100],df_teste[0:100])
# Out:
# CPU times: user 126 ms, sys: 9.81 ms, total: 135 ms
# Wall time: 135 ms
#                                                       A  \
# 4308  ['Tênis Usthemp Short Temá\x81tico - Maria Vir...
# 2259             ['Tênis Skechers Go Walk Joy Marinho']
# 208   ['Tênis Usthemp Short Temá\x81tico - Maria Vir...
# 2121  ['Tenis Feminino De Fazer Caminhada Corrida Ac...
# 7935         ['Tênis Feminino Top Star Injetado Preto']
# 851   ['Tenis Infantil Preto Molekinho/ Dia Das Cria...
# 6565  ['Tênis Feminino Beira Rio Esportivo Sem Cadar...
# 7415         ['Tênis Infantil Feminino Kidy Hype Nude']
# 7463  ['Tênis Infantil Menina Fashion Kids Moda Femi...
# 6438                               ['Tenis Due Sport ']
# 3408  ['Tênis Usthemp Short Temá\x81tico - Maria Vir...
# 6217  ['Tenis  Feminino Pimenta Doce Plataforma Chun...
# 67    ['Tênis Olympikus Pride 2 Feminino Verde E Rosa
# 1035  ['Tênis Feminino Infantil Cano Alto Estrela Co...   0.741695
# 4041  ['Tênis Chunky Sneaker Feminino Blogueiras Pro...   0.741462
# 8814  ['Tênis Infantil Menina Barbie Calça Fácil S/ ...   0.741205
# 498     ['Tênis Star Baby Sapatinho Conforto + Brinde']   0.741071
# 8585  ['Tenis Masculino Preto Trisse Confort Origina...   0.741036
# 1103  ['Tênis Masculino Sport Academia/caminhada Esp...   0.740955
# 4494  ['Tênis Feminino Casual Sapatenis Feminina Con...   0.740655
# 7941   ['Tênis Feminino Verde Militar Loucos & Santos']   0.740358
# 8746            ['Tv Sony Trinitron Wega 29 Polegadas']   0.740316

# %% [markdown]
# A função criada e testada com as 100 primeiras linhas dos dois dataframes está bem sucedida.

# %% [markdown]
# ## 4.1. Utilizando PySpark <a class="anchor" id="section_4_1"></a>

# %% [markdown]
# Iniciando Sessão PySpark

# %%
spark = SparkSession.builder \
    .master("local[1]") \
    .appName("similitud") \
    .getOrCreate()

# %% [markdown]
# Convertendo os dataframes iniciais em dataframes pyspark

# %%
sparkDF =spark.createDataFrame(df) 
sparkDF_test=spark.createDataFrame(df_teste)
sparkDF_test = sparkDF_test.selectExpr("ITE_ITEM_TITLE as TITLE")
sparkDF.printSchema()
sparkDF.show()
# Out:
# root
#  |-- ITE_ITEM_TITLE: string (nullable = true)
#
# +--------------------+
# |      ITE_ITEM_TITLE|
# +--------------------+
# |Tênis Ascension P...|
# |Tenis Para Caminh...|
# |Tênis Feminino Le...|
# |Tênis Olympikus E...|
# |Inteligente Led B...|
# |Tênis Casual Masc...|
# |Tênis Infantil Or...|
# |Tv Samsung Qled 8...|
# |Tênis Usthemp Sho...|
# |Sapatênis West Co...|
# |Sapatilha Bike Ab...|
# |Sapatenis Casual ...|
# |Kit Tênis Slip Fe...|
# |adidas Superstar ...|
# |Tênis Molekinha C...|
# |Tênis Infantil Fe...|
# |Bicicleta Masculi...|
# |Tenis  Feminino P...|
# |Smart Tv Led 40 P...|
# |Tênis Actvitta Se...|
# +--------------------+
# only showing top 20 rows

# %% [markdown]
# Fazendo o cross join entre os dois conjuntos de dados

# %%
similitud = sparkDF.crossJoin(sparkDF_test)
similitud.show()
# Out:
# +--------------------+--------------------+
# |      ITE_ITEM_TITLE|               TITLE|
# +--------------------+--------------------+
# |Tênis Ascension P...|Tênis Olympikus E...|
# |Tênis Ascension P...|Bicicleta Barra F...|
# |Tênis Ascension P...|Tênis Usthemp Sli...|
# |Tênis Ascension P...|Tênis Casual Femi...|
# |Tênis Ascension P...|Tênis Star Baby S...|
# |Tênis Ascension P...|Tênis Oakley Freq...|
# |Tênis Ascension P...|Tênis Jogging Fem...|
# |Tênis Ascension P...|Under Armour Hovr...|
# |Tênis Ascension P...|Tenis Infantil Fe...|
# |Tênis Ascension P...|Tênis Labellamafi...|
# |Tênis Ascension P...|Tênis Feminino In...|
# |Tênis Ascension P...|Tênis Masculino S...|
# |Tênis Ascension P...|Sapatilhas Sapato...|
# |Tênis Ascension P...|Tenis Ous Emergen...|
# |Tênis Ascension P...|1879202 Tênis Ram...|
# |Tênis Ascension P...|Sapatênis Couro L...|
# |Tênis Ascension P...|Tenis Feminino Ca...|
# |Tênis Ascension P...|Tênis Fila D-form...|
# |Tênis Ascension P...|Tênis Infantil Pé...|
# |Tênis Ascension P...|Tênis Feminino Lu...|
# +--------------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# Verificando a dimensão de cada dataframe em pyspark

# %%
print((sparkDF.count(), len(sparkDF.columns)))
# Out:
# (30000, 1)

# %%
print((sparkDF_test.count(), len(sparkDF_test.columns)))
# Out:
# (10000, 1)

# %%
print((similitud.count(), len(similitud.columns)))
# Out:
# (300000000, 2)

# %% [markdown]
# ## 4.2. Utilizando a função Jaro_Winkler para calcular a similaridade <a class="anchor" id="section_4_2"></a>

# %%
@udf(DoubleType())
def jaro_winkler(s1, s2):
    return jellyfish.jaro_winkler(s1, s2)

# %%
similitud = similitud.withColumn('Score Similitud (0,1)',jaro_winkler(col('ITE_ITEM_TITLE'),col('TITLE')))

# %%
similitud.show()
# Out:
# +--------------------+--------------------+---------------------+
# |      ITE_ITEM_TITLE|               TITLE|Score Similitud (0,1)|
# +--------------------+--------------------+---------------------+
# |Tênis Ascension P...|Tênis Olympikus E...|   0.8229761904761904|
# |Tênis Ascension P...|Bicicleta Barra F...|   0.5815016034710432|
# |Tênis Ascension P...|Tênis Usthemp Sli...|   0.6544096133751306|
# |Tênis Ascension P...|Tênis Casual Femi...|   0.6547803617571059|
# |Tênis Ascension P...|Tênis Star Baby S...|   0.6056529516994633|
# |Tênis Ascension P...|Tênis Oakley Freq...|    0.607008547008547|
# |Tênis Ascension P...|Tênis Jogging Fem...|   0.6156060606060606|
# |Tênis Ascension P...|Under Armour Hovr...|   0.6084608799863037|
# |Tênis Ascension P...|Tenis Infantil Fe...|   0.5345264577013819|
# |Tênis Ascension P...|Tênis Labellamafi...|   0.6202645502645503|
# |Tênis Ascension P...|Tênis Feminino In...|   0.6313794289645683|
# |Tênis Ascension P...|Tênis Masculino S...|   0.6725067385444743|
# |Tênis Ascension P...|Sapatilhas Sapato...|   0.5525774400935126|
# |Tênis Ascension P...|Tenis Ous Emergen...|   0.6028395061728395|
# |Tênis Ascension P...|1879202 Tênis Ram...|                 0.44|
# |Tênis Ascension P...|Sapatênis Couro L...|     0.54504895700298|
# |Tênis Ascension P...|Tenis Feminino Ca...|   0.6015743643329851|
# |Tênis Ascension P...|Tênis Fila D-form...|   0.6107575757575757|
# |Tênis Ascension P...|Tênis Infantil Pé...|   0.6440065681444992|
# |Tênis Ascension P...|Tênis Feminino Lu...|    0.644247258225324|
# +--------------------+--------------------+---------------------+
# only showing top 20 rows

# %% [markdown]
# ## 4.3. Ordenando os resultados <a class="anchor" id="section_4_3"></a>

# %%
similitud = df1_x_df2.sort(col("Jaro_Winkler").desc())

# %%
similitud.show(30, truncate=False)

# %% [markdown]
# Com os comandos acima a lista final é ordenada conforme o score da função de similaridade Jaro Winkler, do maior para o menor valor
